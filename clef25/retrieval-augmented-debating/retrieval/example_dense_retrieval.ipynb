# %% [markdown]
# # Touché 25 RAD Examples
# ## Example: Retrieve arguments with dense retrieval

# %% [markdown]
# #### 1. Install requirements

# %%
import json
# %pip install elasticsearch~=8.15.1
# %pip install sentence-transformers
# %pip install xformers
# Out:
# Requirement already satisfied: elasticsearch~=8.15.1 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (8.15.1)
# Requirement already satisfied: elastic-transport<9,>=8.13 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from elasticsearch~=8.15.1) (8.15.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from elastic-transport<9,>=8.13->elasticsearch~=8.15.1) (2.2.3)
# Requirement already satisfied: certifi in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from elastic-transport<9,>=8.13->elasticsearch~=8.15.1) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sentence-transformers in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (3.1.1)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sentence-transformers) (4.45.2)
# Requirement already satisfied: tqdm in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sentence-transformers) (2.5.0)
# Requirement already satisfied: scikit-learn in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sentence-transformers) (0.25.1)
# Requirement already satisfied: Pillow in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.0)
# Requirement already satisfied: setuptools in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.20.0)
# Requirement already satisfied: joblib>=1.2.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: xformers in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (0.0.28.post2)
# Requirement already satisfied: numpy in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from xformers) (2.1.2)
# Requirement already satisfied: torch==2.5.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from xformers) (2.5.0)
# Requirement already satisfied: filelock in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (4.12.2)
# Requirement already satisfied: networkx in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (3.3)
# Requirement already satisfied: jinja2 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (3.1.4)
# Requirement already satisfied: fsspec in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (3.1.0)
# Requirement already satisfied: setuptools in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from torch==2.5.0->xformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch==2.5.0->xformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/nvme/webis-github/TOUCHE-25/touche25-code/retrieval-augmented-debating/data-preprocessing/.venv/lib/python3.12/site-packages (from jinja2->torch==2.5.0->xformers) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### 2. Connect to Elasticsearch

# %%
from elasticsearch import Elasticsearch

# Uncomment if you use a local Elasticsearch instance 
# elasticsearch_url = "http://localhost:9200"

# Uncomment if you use the hosted index from the task organizers
elasticsearch_url = "https://touche25-rad.webis.de/arguments/"

es_client = Elasticsearch(elasticsearch_url, retry_on_timeout=True)
index_name = "claimrev"

query = "pineapple belongs on pizza"

# %% [markdown]
# #### 3. Embed a query

# %% [markdown]
# ##### 3a. Use Stella embeddings

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer("dunzhang/stella_en_400M_v5", trust_remote_code=True)

query_embedding = embedding_model.encode(query, prompt_name="s2p_query")

text_field = "text_embedding_stella"
supports_field = "supports_embedding_stella"
attacks_field = "attacks_embedding_stella"
# Out:
# Some weights of the model checkpoint at dunzhang/stella_en_400M_v5 were not used when initializing NewModel: ['new.pooler.dense.bias', 'new.pooler.dense.weight']
# - This IS expected if you are initializing NewModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing NewModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# #### 4. Retrieve arguments

# %% [markdown]
# ##### Search based on the text field

# %%
import json

# Search based on the argument text
resp = es_client.search(
    index=index_name,
    knn={
        "field": text_field,
        "query_vector": query_embedding,
        "k": 10,
        "num_candidates": 100
    },
)

for hit in resp["hits"]["hits"]:
    # Remove embedding vectors for displaying purposes
    del hit["_source"]["attacks_embedding_stella"]
    # del hit["_source"]["attacks_embedding_colbert"]
    del hit["_source"]["supports_embedding_stella"]
    # del hit["_source"]["supports_embedding_colbert"]
    del hit["_source"]["text_embedding_stella"]
    # del hit["_source"]["text_embedding_colbert"]
    
    print(json.dumps(hit["_source"], indent=2))
# Out:
# {
#   "id": "10104.845",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "The nature of pizza prevents pineapple from being on it.",
#   "supports": "The nature of pizza does not prevent pineapple from being on it.",
#   "text": "Nothing in the definition of the word 'pizza' says that pineapple should not or does not belong on it",
#   "references": [
#     "https://www.merriam-webster.com/dictionary/pizza"
#   ],
#   "original": "attacks"
# }
# {
#   "id": "10104.1196",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Torture is right. In today's day and age, we should not have moved beyond this kind of barbarism.",
#   "supports": "Torture is wrong. In today's day and age, we should have moved well beyond this kind of barbarism. It's cruel to a tropical fruit to be stuck on top of a pizza and be shoved into an oven.",
#   "text": "Being a tropical fruit, pineapples are pretentious that has no place on pizza. They demand a higher respect than that for their stature and well-being.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.3",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "Pineapple on pizza is an insult to the Italian origins of pizza.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.885",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "The nature of pizza prevents pineapple from being on it.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.455",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "The sweetness of the pineapple is a good fit for the general taste of the pizza.",
#   "supports": "The sweetness of the pineapple is a bad fit for the general taste of the pizza.",
#   "text": "All that pineapple does on a pizza is disturb the harmony of all other savoury ingredients. It's such a spoilsport.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.657",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "The nature of pizza does not prevent pineapple from being on it.",
#   "supports": "The nature of pizza prevents pineapple from being on it.",
#   "text": "Pineapples cannot belong on pizzas, as they are not pizza's property (because pizzas have no rights to own property). Because pizzas don't own or buy pineapples, they cannot claim that pineapples belong on them nor tell others that pineapples are theirs and belong on their pizza turf.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.1076",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "The nature of pizza does not prevent pineapple from being on it.",
#   "supports": "The nature of pizza prevents pineapple from being on it.",
#   "text": "Pineapple on pizza creates more harm than good for certain instances, so it ought not to be present on it.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.895",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "From a culinary point of view, it's always a good thing to have another recipe to make.",
#   "supports": "It's not always a good thing to have another recipe to make.",
#   "text": "There are more optimal culinary placement options for pineapple than on pizza.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.829",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "The definition of the word 'pizza' says that pineapple should not or does not belong on it.",
#   "supports": "Nothing in the definition of the word 'pizza' says that pineapple should not or does not belong on it",
#   "text": "Pineapple on pizza has nothing wrong with it. Most people don't like it with no reason or just because they don't like pineapple.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.848",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not provide aesthetic tastes and taste experiences.",
#   "supports": "Pineapple provides aesthetic tastes and taste experiences.",
#   "text": "Pineapple on pizza gives it more flavor.",
#   "references": [],
#   "original": "supports"
# }

# %% [markdown]
# ##### Search based on argument supports

# %%
import json

# Search based on the support
resp = es_client.search(
    index=index_name,
    knn={
        "field": supports_field,
        "query_vector": query_embedding,
        "k": 10,
        "num_candidates": 100
    },
)

for hit in resp["hits"]["hits"]:
    # Remove embedding vectors for displaying purposes
    del hit["_source"]["attacks_embedding_stella"]
    # del hit["_source"]["attacks_embedding_colbert"]
    del hit["_source"]["supports_embedding_stella"]
    # del hit["_source"]["supports_embedding_colbert"]
    del hit["_source"]["text_embedding_stella"]
    # del hit["_source"]["text_embedding_colbert"]
    
    print(json.dumps(hit["_source"], indent=2))
# Out:
# {
#   "id": "10104.349",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not belong on pizza.",
#   "supports": "Pineapple belongs on pizza.",
#   "text": "Pineapples make pizza aesthetically pleasing.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.425",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not belong on pizza.",
#   "supports": "Pineapple belongs on pizza.",
#   "text": "It's no coincidence that pineapple and pizza both start with pi.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.2225",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not belong on pizza.",
#   "supports": "Pineapple belongs on pizza.",
#   "text": "Pineapple is cheaper than other toppings",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.39",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not belong on pizza.",
#   "supports": "Pineapple belongs on pizza.",
#   "text": "Pineapple makes pizza healthier to eat.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.4",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not belong on pizza.",
#   "supports": "Pineapple belongs on pizza.",
#   "text": "From a culinary point of view, it's always a good thing to have another recipe to make.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.715",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "While some benefit from pineapples being on pizza, other living beings suffer from it.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.885",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "The nature of pizza prevents pineapple from being on it.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.1065",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "Because of the incredible passion people have against putting pineapples on pizza, we ought not to combine the two, thus ending existing conflict and reducing the chance of future conflict, altogether leading towards world peace.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.2242",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "Pineapple on pizza leaves less room for more meat.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.742",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "Pineapple agriculture is bad for the environment.",
#   "references": [],
#   "original": "attacks"
# }

# %% [markdown]
# ##### Search based on the argument attacks

# %%
import json

# Search based on the support
resp = es_client.search(
    index=index_name,
    knn={
        "field": attacks_field,
        "query_vector": query_embedding,
        "k": 10,
        "num_candidates": 100
    },
)

for hit in resp["hits"]["hits"]:
    # Remove embedding vectors for displaying purposes
    del hit["_source"]["attacks_embedding_stella"]
    # del hit["_source"]["attacks_embedding_colbert"]
    del hit["_source"]["supports_embedding_stella"]
    # del hit["_source"]["supports_embedding_colbert"]
    del hit["_source"]["text_embedding_stella"]
    # del hit["_source"]["text_embedding_colbert"]
     
    print(json.dumps(hit["_source"], indent=2))
# Out:
# {
#   "id": "10104.715",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "While some benefit from pineapples being on pizza, other living beings suffer from it.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.885",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "The nature of pizza prevents pineapple from being on it.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.1065",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "Because of the incredible passion people have against putting pineapples on pizza, we ought not to combine the two, thus ending existing conflict and reducing the chance of future conflict, altogether leading towards world peace.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.2242",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "Pineapple on pizza leaves less room for more meat.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.742",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "Pineapple agriculture is bad for the environment.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.3",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple belongs on pizza.",
#   "supports": "Pineapple does not belong on pizza.",
#   "text": "Pineapple on pizza is an insult to the Italian origins of pizza.",
#   "references": [],
#   "original": "attacks"
# }
# {
#   "id": "10104.1288",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapples belong on pizza.",
#   "supports": "Humans decide to put pineapples on pizza (as humans own pizza's property). Since both pineapples and pizzas were not taken into confidence, pineapples don't belong there until this happens and the permission is granted then by them.",
#   "text": "Asking permission from all parties is the true determiner of this dilemma. Only then could one reach a true consensus, because everyone's opinions were laid out and counted.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.349",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not belong on pizza.",
#   "supports": "Pineapple belongs on pizza.",
#   "text": "Pineapples make pizza aesthetically pleasing.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.425",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not belong on pizza.",
#   "supports": "Pineapple belongs on pizza.",
#   "text": "It's no coincidence that pineapple and pizza both start with pi.",
#   "references": [],
#   "original": "supports"
# }
# {
#   "id": "10104.2225",
#   "topic": "Does pineapple belong on pizza?",
#   "tags": [
#     "Food",
#     "Pizza",
#     "Hawaiian",
#     "Pineapple"
#   ],
#   "attacks": "Pineapple does not belong on pizza.",
#   "supports": "Pineapple belongs on pizza.",
#   "text": "Pineapple is cheaper than other toppings",
#   "references": [],
#   "original": "supports"
# }
